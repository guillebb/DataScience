# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('w_data.csv', sep =";")
df1
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
# 48842       Self-emp-inc  182148.0           0.0           0.0
#
#        Hours per week          ID   Target
# 0                40.0       49084    <=50K
# 1                13.0       68553    <=50K
# 2                40.0      143654    <=50K
# ...

# %%
df2 = pd.read_csv('p_data.csv', sep =";")
df2
# Out:
#         Age      Sex          ID                 Race         Country  \
# 0      39.0     Male       49084                White   United-States
# 1      50.0     Male       68553                White   United-States
# 2      38.0     Male      143654                White   United-States
# 3      53.0     Male       41510                Black   United-States
# 4      28.0   Female      195025                Black            Cuba
# ...     ...      ...         ...                  ...             ...
# 48837  33.0     Male   597186815                White   United-States
# 48838  39.0   Female   735617153                White   United-States
# 48839  64.0     Male  1131807446                Black   United-States
# 48840  38.0     Male   781422087                White   United-States
# 48841  44.0     Male   161771296   Asian-Pac-Islander   United-States
#
#         Education  Education-Num       Marital Status     Relationship
# ...

# %% [markdown]
# 1- Cuantos ID tienen en común. Nombrar cuales no tienen en común

# %%
df = pd.merge(df1, df2, on="ID")
df
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48837            Private  245211.0           0.0           0.0
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
#
#        Hours per week          ID   Target   Age      Sex  \
# 0                40.0       49084    <=50K  39.0     Male
# 1                13.0       68553    <=50K  50.0     Male
# ...

# %%
len(df1.value_counts('ID'))
# Out:
# 48843

# %%
len(df2.value_counts('ID'))
# Out:
# 48842

# %%
len(df.value_counts('ID'))
# Out:
# 48842

# %%
df0 = pd.merge(df1,df2, how='left', on="ID", indicator=True)
df0
# Out:
#                Workclass    fnlwgt  Capital Gain  Capital Loss  \
# 0              State-gov   77516.0        2174.0           0.0
# 1       Self-emp-not-inc   83311.0           0.0           0.0
# 2                Private  215646.0           0.0           0.0
# 3                Private  234721.0           0.0           0.0
# 4                Private  338409.0           0.0           0.0
# ...                  ...       ...           ...           ...
# 48838            Private  215419.0           0.0           0.0
# 48839                  ?  321403.0           0.0           0.0
# 48840            Private  374983.0           0.0           0.0
# 48841            Private   83891.0        5455.0           0.0
# 48842       Self-emp-inc  182148.0           0.0           0.0
#
#        Hours per week          ID   Target   Age      Sex  \
# 0                40.0       49084    <=50K  39.0     Male
# 1                13.0       68553    <=50K  50.0     Male
# ...

# %% [markdown]
# Tienen 48842 ID en común, uno solo no tienen en común: el ID= 1344995623

# %%
df_exclude = df0[df0['_merge'] == 'left_only']
df_exclude
# Out:
#            Workclass    fnlwgt  Capital Gain  Capital Loss  Hours per week  \
# 48842   Self-emp-inc  182148.0           0.0           0.0            60.0
#
#                ID  Target  Age  Sex Race Country Education  Education-Num  \
# 48842  1344995623   >50K.  NaN  NaN  NaN     NaN       NaN            NaN
#
#       Marital Status Relationship     _merge
# 48842            NaN          NaN  left_only

# %% [markdown]
# 2- Corregir los target a solo dos valores distintos ‘<=50k’ y ‘>50k’

# %%
df["Target"].value_counts()
# Out:
#  <=50K     24720
#  <=50K.    12435
#  >50K       7841
#  >50K.      3845
# Name: Target, dtype: int64

# %%
df0 = df0.replace(to_replace="<=50K", value="<=50k", regex=True)
df0 = df0.replace(to_replace="<=50k.", value="<=50k", regex=True)
df0 = df0.replace(to_replace=">50K", value=">50k", regex=True)
df0= df0.replace(to_replace=">50k.", value=">50k", regex=True)

# %%
valores = df0["Target"].value_counts()
valores
# Out:
#  <=50k    37155
#  >50k     11687
# Name: Target, dtype: int64

# %% [markdown]
# 3- Calcular la proporción que hay entre personas con salarios >50k respecto del total para Entre personas de distinto sexo, Raza y Educacion. Por ejemplo cuál es el porcentaje de mujeres con un salario mayor a 50K y compararlo con el de los hombres. Lo mismo para personas de distintas razas y Educación ( group by para cada una de las condiones)

# %%
genero= df0["Target"].groupby([df0["Sex"], df0["Target"]]).count()
genero
# Out:
# Sex      Target
#  Female   <=50k    14423
#           >50k      1769
#  Male     <=50k    22732
#           >50k      9917
# Name: Target, dtype: int64

# %%
genero.unstack(level="Sex")
# Out:
# Sex      Female   Male
# Target
#  <=50k    14423  22732
#  >50k      1769   9917

# %%
educacion = df0["Target"].groupby([df0["Education"], df0["Target"]]).count()
educacion
# Out:
# Education      Target
#  10th           <=50k     1302
#                 >50k        87
#  11th           <=50k     1720
#                 >50k        92
#  12th           <=50k      609
#                 >50k        48
#  1st-4th        <=50k      239
#                 >50k         8
#  5th-6th        <=50k      482
#                 >50k        27
#  7th-8th        <=50k      893
#                 >50k        62
#  9th            <=50k      715
#                 >50k        41
#  Assoc-acdm     <=50k     1188
#                 >50k       413
#  Assoc-voc      <=50k     1539
#                 >50k       522
#  Bachelors      <=50k     4712
#                 >50k      3312
#  Doctorate      <=50k      163
#                 >50k       431
#  HS-grad        <=50k    13281
#                 >50k      2503
#  Masters        <=50k     1198
#                 >50k      1459
#  Preschool      <=50k       82
#                 >50k         1
#  Prof-school    <=50k      217
# ...

# %%
race = df0["Target"].groupby([df0["Race"], df0["Target"]]).count()
race
# Out:
# Race                 Target
#  Amer-Indian-Eskimo   <=50k      415
#                       >50k        55
#  Asian-Pac-Islander   <=50k     1110
#                       >50k       409
#  Black                <=50k     4119
#                       >50k       566
#  Other                <=50k      356
#                       >50k        50
#  White                <=50k    31155
#                       >50k     10606
# Name: Target, dtype: int64
